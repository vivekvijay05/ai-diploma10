# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = load_iris()
X = data['data']
y = data['target']
feature_names = data['feature_names']
class_names = data['target_names']

print("Features:", feature_names)
print("Classes:", class_names)
print("X shape:", X.shape, " y shape:", y.shape)
# Out:
# Features: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Classes: ['setosa' 'versicolor' 'virginica']
# X shape: (150, 4)  y shape: (150,)

# %%
for i in range(3):
    print(class_names[i], "examples:", np.sum(y==i))
# Out:
# setosa examples: 50
# versicolor examples: 50
# virginica examples: 50

# %%
import tensorflow as tf
SEED = 42
import random
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# 40,30,30  -->  40,30,30

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.15, stratify=y, random_state=SEED)

X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.15, stratify=y_train_val, random_state=SEED)

print("Train:", X_train.shape, "Val:", X_val.shape, "Test:", X_test.shape)
# Out:
# Train: (107, 4) Val: (20, 4) Test: (23, 4)

# %%
# Scale features (important for ANN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)
X_test_scaled  = scaler.transform(X_test)

# %%
print(X_train_scaled)

# %%
print(X_train_scaled.shape[1])
# Out:
# 4

# %%
X_train_scaled.shape[1]
# Out:
# 4

# %%
import pandas as pd

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, InputLayer
from tensorflow.keras.optimizers import Adam

model = Sequential([
    InputLayer(input_shape=(X_train_scaled.shape[1],)),
    Dense(16, activation='relu'),
    Dense(12, activation='relu'),
    Dense(3, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)




model.fit(X_train,y_train,epochs=50,validation_split=0.2)
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.3092 - loss: 1.9169 - val_accuracy: 0.6818 - val_loss: 1.1162
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5048 - loss: 1.1602 - val_accuracy: 0.2727 - val_loss: 1.1038
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3288 - loss: 1.0419 - val_accuracy: 0.5000 - val_loss: 1.1395
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5028 - loss: 1.0268 - val_accuracy: 0.2727 - val_loss: 1.0796
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3796 - loss: 0.9645 - val_accuracy: 0.5000 - val_loss: 0.9370
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6007 - loss: 0.8685 - val_accuracy: 0.6818 - val_loss: 0.8387
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6556 - loss: 0.8166 - val_accuracy: 0.7273 - val_loss: 0.7697
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6380 - loss: 0.7823 - val_accuracy: 0.7273 - val_loss: 0.7105
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6380 - loss: 0.7424 - val_accuracy: 0.7273 - val_loss: 0.6507
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6615 - loss: 0.6856 - val_accuracy: 0.7273 - val_loss: 0.5836
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7457 - loss: 0.6198 - val_accuracy: 0.9091 - val_loss: 0.5230
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8435 - loss: 0.5636 - val_accuracy: 1.0000 - val_loss: 0.4737
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9315 - loss: 0.5188 - val_accuracy: 1.0000 - val_loss: 0.4201
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9667 - loss: 0.4735 - val_accuracy: 1.0000 - val_loss: 0.3678
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9491 - loss: 0.4312 - val_accuracy: 0.9545 - val_loss: 0.3257
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9315 - loss: 0.3986 - val_accuracy: 1.0000 - val_loss: 0.2911
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9315 - loss: 0.3693 - val_accuracy: 1.0000 - val_loss: 0.2594
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9491 - loss: 0.3401 - val_accuracy: 1.0000 - val_loss: 0.2324
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9491 - loss: 0.3128 - val_accuracy: 1.0000 - val_loss: 0.2107
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9667 - loss: 0.2891 - val_accuracy: 1.0000 - val_loss: 0.1908
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9667 - loss: 0.2684 - val_accuracy: 1.0000 - val_loss: 0.1701
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9569 - loss: 0.2488 - val_accuracy: 1.0000 - val_loss: 0.1513
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9745 - loss: 0.2307 - val_accuracy: 1.0000 - val_loss: 0.1352
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9843 - loss: 0.2151 - val_accuracy: 1.0000 - val_loss: 0.1200
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9745 - loss: 0.2011 - val_accuracy: 1.0000 - val_loss: 0.1067
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9745 - loss: 0.1885 - val_accuracy: 1.0000 - val_loss: 0.0957
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9745 - loss: 0.1775 - val_accuracy: 1.0000 - val_loss: 0.0858
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9648 - loss: 0.1679 - val_accuracy: 1.0000 - val_loss: 0.0771
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9648 - loss: 0.1592 - val_accuracy: 1.0000 - val_loss: 0.0700
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9648 - loss: 0.1516 - val_accuracy: 1.0000 - val_loss: 0.0636
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9648 - loss: 0.1449 - val_accuracy: 1.0000 - val_loss: 0.0578
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9648 - loss: 0.1390 - val_accuracy: 1.0000 - val_loss: 0.0531
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9648 - loss: 0.1337 - val_accuracy: 1.0000 - val_loss: 0.0488
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9648 - loss: 0.1291 - val_accuracy: 1.0000 - val_loss: 0.0449
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9648 - loss: 0.1249 - val_accuracy: 1.0000 - val_loss: 0.0416
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9648 - loss: 0.1212 - val_accuracy: 1.0000 - val_loss: 0.0386
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9648 - loss: 0.1179 - val_accuracy: 1.0000 - val_loss: 0.0359
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9648 - loss: 0.1149 - val_accuracy: 1.0000 - val_loss: 0.0335
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9648 - loss: 0.1121 - val_accuracy: 1.0000 - val_loss: 0.0314
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9648 - loss: 0.1097 - val_accuracy: 1.0000 - val_loss: 0.0295
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9648 - loss: 0.1074 - val_accuracy: 1.0000 - val_loss: 0.0278
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9648 - loss: 0.1053 - val_accuracy: 1.0000 - val_loss: 0.0263
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9648 - loss: 0.1034 - val_accuracy: 1.0000 - val_loss: 0.0248
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9648 - loss: 0.1017 - val_accuracy: 1.0000 - val_loss: 0.0236
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9648 - loss: 0.1001 - val_accuracy: 1.0000 - val_loss: 0.0224
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9648 - loss: 0.0986 - val_accuracy: 1.0000 - val_loss: 0.0214
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9648 - loss: 0.0972 - val_accuracy: 1.0000 - val_loss: 0.0204
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9648 - loss: 0.0959 - val_accuracy: 1.0000 - val_loss: 0.0195
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9648 - loss: 0.0946 - val_accuracy: 1.0000 - val_loss: 0.0187
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9745 - loss: 0.0935 - val_accuracy: 1.0000 - val_loss: 0.0179

# %%
X_train_scaled

# %%
y_test
# Out:
# array([1, 2, 1, 1, 0, 1, 0, 0, 2, 1, 1, 2, 2, 2, 0, 0, 1, 2, 1, 0, 2, 0,
#        2])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 12)             │           204 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 3)              │            39 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 971 (3.80 KB)
#  Trainable params: 323 (1.26 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 648 (2.54 KB)

# %%
import tensorflow as tf

y_train_one_hot = tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test_one_hot = tf.keras.utils.to_categorical(y_test, num_classes=3)

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_scaled, y_train_one_hot, epochs=5, validation_split=0.2)
# Out:
# Epoch 1/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 0.2114 - loss: 1.1043 - val_accuracy: 0.2727 - val_loss: 1.1108
# Epoch 2/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3209 - loss: 1.0909 - val_accuracy: 0.2727 - val_loss: 1.0996
# Epoch 3/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3757 - loss: 1.0785 - val_accuracy: 0.2727 - val_loss: 1.0889
# Epoch 4/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4011 - loss: 1.0666 - val_accuracy: 0.3182 - val_loss: 1.0785
# Epoch 5/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4873 - loss: 1.0552 - val_accuracy: 0.3182 - val_loss: 1.0682

# %%
test_loss, test_mae = model.evaluate(X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.0768
