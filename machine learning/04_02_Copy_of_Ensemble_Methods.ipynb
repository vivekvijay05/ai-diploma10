# %% [markdown]
# #Bagging
#
# Bagging (Bootstrap Aggregating) is an ensemble learning technique that improves model performance by training multiple models independently on different random subsets of the training data and then aggregating their predictions.

# %% [markdown]
# - Create multiple datasets using bootstrapping
# (random sampling with replacement)
#
# - Train independent models on each dataset
#
# - Each model gives a prediction
#
# - Combine predictions:
#
#    - Classification → Majority vote
#
#    - Regression → Average

# %% [markdown]
# ###Why Bagging?
#
# - Reduces variance
# - Prevents overfitting
# - Works well with high-variance models
# - Easy to parallelize
#
# ### Limitations
#
# - Does not reduce bias
#
# - Less effective if base models are already stable

# %% [markdown]
# ###Bagging Algorithm
#
#     Random Forest (Ensemble of decision trees)
#
# Uses:
#
#     - Bootstrapped datasets
#
#     - Random feature selection
#
#     - Strong, robust, and widely used

# %% [markdown]
# ### When to Use Bagging?
#
# - When model overfits
# - When using decision trees
# - When data is noisy
# - When training can be parallelized
#
# ### Avoid if
#
# - Model underfits
#
# - Dataset is very small

# %% [markdown]
# # Boosting
#   Boosting is a machine learning ensemble technique that combines multiple weak learners to create a strong learner with high accuracy.

# %% [markdown]
# - Train a simple model (usually a shallow decision tree)
#
# - Identify misclassified samples
#
# - Give higher importance (weight) to those samples
#
# - Train the next model focusing on them
#
# - Repeat this process
#
# - Combine all models using weighted voting or summation

# %% [markdown]
# ###Why Boosting ?
#
# - Reduces bias
# - Improves accuracy
# - Works well with complex patterns
# - Handles non-linear relationships

# %% [markdown]
# ### Limitations
#
# - Sensitive to noise & outliers
#
# - Can overfit if not regularized

# %% [markdown]
# ### When Should You Use Boosting?
#
# - When model underfits
# - When accuracy is critical
# - When dataset is medium to large
# - When features are complex
#
#
# ### Avoid if:
#
# - Data has many outliers
#
# - Dataset is extremely noisy

# %% [markdown]
# ###Boosting vs Bagging
#
# | Feature     | Boosting       | Bagging         |
# | ----------- | -------------- | --------------- |
# | Training    | Sequential     | Parallel        |
# | Focus       | Correct errors | Reduce variance |
# | Overfitting | Possible       | Less            |
# | Example     | AdaBoost       | Random Forest   |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Boosting Algorithms

# %% [markdown]
# ###AdaBoost (Adaptive Boosting)
#
# - First boosting algorithm
#
# - Increases weight of misclassified points
#
# - Uses weighted majority voting
#
# - Best for clean datasets

# %% [markdown]
# ###Gradient Boosting
#
# - Uses gradient descent to minimize loss
#
# - Each new model learns the residual errors
#
# - Very flexible and powerful

# %% [markdown]
# ### XGBoost (Extreme Gradient Boosting)
#
# - Optimized version of Gradient Boosting
#
# - Faster + regularization + parallel processing

# %% [markdown]
# ### LightGBM
#
# - Leaf-wise tree growth (faster)
#
# - Works well for large datasets
#
# - Low memory usage

# %% [markdown]
# ### CatBoost
#
# - Designed for categorical features
#
# - Reduces target leakage
#
# - Excellent for real-world business data
