# %% [markdown]
# # Python Self-Assessment Practice Problems

# %% [markdown]
# ## Section 1 – Basics & Syntax

# %%
print("Hello, Python!")

# %%
language = "Python"
print(f"I am learning {language}")

# %%
print("Hello" + "World")
print("5" + "3")

# %% [markdown]
# ## Section 2 – Variables & Data Types

# %%
name = "Alice"
age = 25
print(f"My name is {name} and I am {age} years old. After 12 years my age will be {age + 12}.")

# %%
num1 = 10
num2 = 5
print("Sum:", num1 + num2)
print("Difference:", num1 - num2)
print("Product:", num1 * num2)
print("Quotient:", num1 / num2)

# %% [markdown]
# ## Section 3 – Input & Output

# %%
color = input("What is your favorite color? ")
print(f"Your favorite color is {color}.")

# %%
n1 = float(input("Enter first number: "))
n2 = float(input("Enter second number: "))
average = (n1 + n2) / 2
print("Average:", average)

# %% [markdown]
# ## Section 4 – Comments

# %%
# Get user input
num = int(input("Enter a number: "))
# Multiply the number by 2
double = num * 2
# Print the result
print("Double:", double)

# %%
# This adds two numbers
sum = 5 + 3
print(sum)

# %% [markdown]
# ## Section 5 – Operators

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))
area = length * width
perimeter = 2 * (length + width)
print("Area:", area)
print("Perimeter:", perimeter)

# %%
a = 10
b = 3
print(a // b)
print(a % b)
print(a ** b)

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
if num > 100:
    print("Greater than 100")
else:
    print("Not greater than 100")

# %%
x = 10
x += 5
x *= 3
print("Final value:", x)

# %% [markdown]
# ## Section 6 – Mini Challenges

# %%
# Temperature Converter
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(f"Temperature in Fahrenheit: {fahrenheit}")

# %%
# Simple Interest Calculator
principal = float(input("Enter principal: "))
rate = float(input("Enter rate: "))
time = float(input("Enter time: "))
interest = (principal * rate * time) / 100
print(f"Simple Interest: {interest}")

# %%
# Swap Two Variables Without Using Third Variable
a = int(input("Enter value of a: "))
b = int(input("Enter value of b: "))
a, b = b, a
print(f"After swapping: a = {a}, b = {b}")
